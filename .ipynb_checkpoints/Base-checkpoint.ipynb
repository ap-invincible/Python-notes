# %%
list1 = [10,20,30,40,50]
list2 = []DataData
i = len(list1)-1

while i >= 0:
    list2.append(list1[i])
    i = i-1;
print(list2)
# Out:
# [50, 40, 30, 20, 10]

# %%
j = 0
while i<j:
    temp = list1[i]
    list1[i]=list1[j]
    list1[j] = temp
    i = i+1
    j = j-1
print(list1)
# Out:
# [50, 20, 30, 40, 10]

# %% [markdown]
# Question - 2
# Given a list of marks, count how many students scored:
#     1. above 75
#     2. below 40
#
# Test cases:
#     1. input = [19,40,90,91,52,75,20]
#        output = above 75 - 2
#                 below 40 - 2
#
#     2. input = [29,70,90,91,52,75,20]
#        output = above 75 - 3
#                 below 40 - 2
#
#     3. input = [19,40,90,91,52,75,20]
#        output = above 75 - 2
#                 below 40 - 1

# %% [markdown]
# Exercise 1:
# Create a tuple of 5 cities.
# 1. Print first and last city.
# 2. Check if delhi exists.
#
# Test cases:
# 1. t1 = (Delhi, Gurugram, Varanasi, Sohna, Prayagraj)
#        Delhi exists
#        1st Delhi
#        Last Prayagraj
# 3. t1 = (Gurugram, Varanasi, Sohna, Prayagraj, Agra)
#        Delhi doesn't exist
#        1st - GUrugram
#        Last - Agra
# 5. t1 = (Agra, Sohna, Mumbai, Pune, Delhi)
#        Delhi Exists
#        1st - Agra
#        Last - Delhi

# %%
t1 = ("Agra","Mumbai","Delhi","Pune","Varanasi")
print("1st city - ",t1[0])
print("Last city - ",t1[-1])
# if "Delhi" in t1:
#     print("Delhi is present in tuple")
# else:
#     Print("Delhi is not in tuple")

while "Delhi" in t1:
    print("Delhi exists")
    break
# Out:
# 1st city -  Agra
# Last city -  Varanasi
# Delhi exists

# %% [markdown]
# OOPS

# %%
class Faculty:
    F_name = None
    age = None
    position = None
    mob_no = None

f1 = Faculty()
f1.F_name = "Anant"
print(f1.F_name)
# Out:
# Anant

# %% [markdown]
# Assignment
#
# Q1
# Write a python program to manage student info using a class named student.
# Class should contain the following data:
#     1. Roll_no
#     2. Name
#     3. Marks
# This class should include 4 methods:
#     1. Take nothing, Return nothing
