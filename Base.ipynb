# %%
list1 = [10,20,30,40,50]
list2 = []DataData
i = len(list1)-1

while i >= 0:
    list2.append(list1[i])
    i = i-1;
print(list2)
# Out:
# [50, 40, 30, 20, 10]

# %%
j = 0
while i<j:
    temp = list1[i]
    list1[i]=list1[j]
    list1[j] = temp
    i = i+1
    j = j-1
print(list1)
# Out:
# [50, 20, 30, 40, 10]

# %% [markdown]
# Question - 2
# Given a list of marks, count how many students scored:
#     1. above 75
#     2. below 40
#
# Test cases:
#     1. input = [19,40,90,91,52,75,20]
#        output = above 75 - 2
#                 below 40 - 2
#
#     2. input = [29,70,90,91,52,75,20]
#        output = above 75 - 3
#                 below 40 - 2
#
#     3. input = [19,40,90,91,52,75,20]
#        output = above 75 - 2
#                 below 40 - 1

# %% [markdown]
# Exercise 1:
# Create a tuple of 5 cities.
# 1. Print first and last city.
# 2. Check if delhi exists.
#
# Test cases:
# 1. t1 = (Delhi, Gurugram, Varanasi, Sohna, Prayagraj)
#        Delhi exists
#        1st Delhi
#        Last Prayagraj
# 3. t1 = (Gurugram, Varanasi, Sohna, Prayagraj, Agra)
#        Delhi doesn't exist
#        1st - Gurugram
#        Last - Agra
# 5. t1 = (Agra, Sohna, Mumbai, Pune, Delhi)
#        Delhi Exists
#        1st - Agra
#        Last - Delhi

# %%
t1 = ("Agra","Mumbai","Delhi","Pune","Varanasi")
print("1st city - ",t1[0])
print("Last city - ",t1[-1])
# if "Delhi" in t1:
#     print("Delhi is present in tuple")
# else:
#     Print("Delhi is not in tuple")

while "Delhi" in t1:
    print("Delhi exists")
    break
# Out:
# 1st city -  Agra
# Last city -  Varanasi
# Delhi exists

# %% [markdown]
# OOPS

# %%
class Faculty:
    F_name = None
    age = None
    position = None
    mob_no = None

f1 = Faculty()
f1.F_name = "Anant"
print(f1.F_name)
# Out:
# Anant

# %% [markdown]
# Assignment
#
# Q1
# Write a python program to manage student info using a class named student.
# Class should contain the following data:
#     1. Roll_no
#     2. Name
#     3. Marks
# This class should include 4 methods:
#     1. Take nothing, Return nothing
#     2. Take something, Return nothing
#     3. Take nothing, Return something
#     4. Take something, Return something

# %%
# class Student:
#     def __init__(self,name,roll_no,marks):
#         self.name = name
#         self.roll_no = roll_no
#         self.marks = marks
#     def display_college():    #Take nothing - Return nothing
#         print("KRMU")
#     def set_data(element,value):    #Take something - Return nothing
#         self.element = value
#     def get_marks():    #Take nothing - Return something
#         return self.marks
#     def calculate_grade():    #Take something - Return something

# %%
matrix = [ [1,2,3,] , [4,5,6] , [7,8,9] ]
n = len(matrix)
m = len(matrix[0])

for i in range(n):
    for j in range(m):
        print(matrix[i][j] , end="")
    print()

sum=0
for i in range(n):
    for j in range(m):
        n = matrix[i][j]
        sum = sum + n
print (sum)
# Out:
# 123
# 456
# 789
# 45

# %%
s = 0
for i in range(n):
    for j in range(0,n,2):
        s+=1
# Out:
# --------------------------------------------------------------
# NameError                    Traceback (most recent call last)
# Cell In[1], line 2
#       1 s = 0
# ----> 2 for i in range(n):
#       3     for j in range(0,n,2):
#       4         s+=1
#
# NameError: name 'n' is not defined

# %% [markdown]
# Arrays                    Linked lists
# 1.Insertion and deletion:

# %%
## Bubble Sort ##
arr1 = [30,10,50,20,40]
n = len(arr1)
for i in range (n-1):
    for j in range(n-1-i):
        if arr1[j] > arr1[j+1]:
            arr1[j] , arr1[j+1] = arr1[j+1] , arr1[j]
print(arr1)
# Out:
# [10, 20, 30, 40, 50]

# %% [markdown]
# ### LINEAR SEARCH ###

# %%
def binarySearch(arr, target):
    low = 0
    high = len(arr1) - 1
    while(low<=high):
        mid = (low+high) / 2
        if (target==arr1[mid]):
            return mid
        elif target > arr1[mid]:
            low = mid + 1
        else:
            high = mid+1
    return -1

# %%
### Merge 2 sorted arrays ###

# %%
def merge_sorted_arrays(arr1, arr2):
    mergedArr = []
    i = j = 0

    while i < len(arr1) and j < len(arr2):
        if arr1[i] < arr2[j]:
            mergedArr.append(arr1[i])
            i += 1
        else:
            mergedArr.append(arr2[j])
            j += 1

    mergedArr.extend(arr1[i:])
    mergedArr.extend(arr2[j:])
    
    return mergedArr

list_a = [1, 3, 5, 7]
list_b = [2, 4, 6, 8, 10]
print(merge_sorted_arrays(list_a, list_b))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 10]
